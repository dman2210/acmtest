# %% [markdown]
# <a href="https://colab.research.google.com/github/dman2210/acmtest/blob/master/Mind_Games_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://hkinsley.com/static/downloads/bci/model_data_v2.7z"
# Out:
# --2020-10-20 03:38:41--  https://hkinsley.com/static/downloads/bci/model_data_v2.7z
# Resolving hkinsley.com (hkinsley.com)... 104.131.100.36
# Connecting to hkinsley.com (hkinsley.com)|104.131.100.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1047773447 (999M) [application/x-7z-compressed]
# Saving to: ‘model_data_v2.7z’
#
# model_data_v2.7z    100%[===================>] 999.23M  16.5MB/s    in 64s
#
# 2020-10-20 03:39:46 (15.7 MB/s) - ‘model_data_v2.7z’ saved [1047773447/1047773447]

# %%
# !apt-get install tar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tar is already the newest version (1.29b-2ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.

# %%
!7z e model_data_v2.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1047773447 bytes (1000 MiB)
#
# Extracting archive: model_data_v2.7z
# --
# Path = model_data_v2.7z
# Type = 7z
# Physical Size = 1047773447
# Headers Size = 22613
# Method = LZMA:23
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 9
# Files: 1230
# Size:       2456797440
# Compressed: 1047773447
